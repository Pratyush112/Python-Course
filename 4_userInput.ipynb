# %% [markdown]
# # User Input:
# <pre>1. Very important for dynamic applications
# 2. user input is always a string, and by performing type conversion, we can convert it to the desired data type. </pre>

# %%
name = input("What is your name?")
print(name)

age = input("What is your age?")
print(age, "This is in string format")

# %% [markdown]
# # To change the type of the string to an integer, we need to perform type conversion using the int() funtion.

# %%
age = input()
print(int(age), "This is in integer format")
# Out:
# 25 This is in integer format

# %%
#another way to get user input and convert it to an integer is: 
age = int(input("What is your age?")) # This is the best practice. 
print(age, "This is in integer format, the industry standard way to get user input and convert it to the desired data type.")
# Out:
# 25 This is in integer format, the industry standard way to get user input and convert it to the desired data type.
