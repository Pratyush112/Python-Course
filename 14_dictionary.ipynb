# %% [markdown]
# ## Dictionary
#
# 1. Collection of data
# 2. Unordered, changed and indexed
# 3. Notation = {}
# 4. In Key value pairs = {"1":"a", "2":"b"}
# 5. Accessing the items value based on key.

# %%
my_dict = {1, 2, 3, 4, 5}
print(type(my_dict))
